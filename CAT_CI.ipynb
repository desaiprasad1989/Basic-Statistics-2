# %% [markdown]
# ### Problem Statement
#
# On the verbal section of the CAT exam, the standard deviation is known to be 100. A sample of 25 test takers has a mean of 520. Construct the 95% Confidence Interval around the mean

# %%
### xbar = 520, sigma = 100, n=25, CI=0.95 appha=0.05
# Confidnce Interval = (n, loc/Mean, SD/Scale)
